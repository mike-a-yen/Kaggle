# %%
import numpy as np
import pandas as pd
from datetime import datetime
from preprocess import *
from useful_tools import *
from sklearn import linear_model
from sklearn.cross_validation import train_test_split
from sklearn.cross_validation import KFold
import matplotlib.pyplot as plt
plt.style.use('bmh')
# %matplotlib inline

# %%
train_raw = pd.read_csv('data_sets/train.csv')

# %%
train = preprocess(train_raw)

# %%
train.to_csv('data_sets/preprocessed_v1.csv')

# %%
train_x = train.drop(['Survived'],axis=1)
train_y = train['Survived'].values
train_x.describe()
# Out:
#            Pclass         Age       SibSp       Parch        Fare      gender  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     2.308642   29.361582    0.523008    0.381594   32.204208    0.647587
# std      0.836071   13.019697    1.102743    0.806057   49.693429    0.477990
# min      1.000000    0.420000    0.000000    0.000000    0.000000    0.000000
# 25%      2.000000   22.000000    0.000000    0.000000    7.910400    0.000000
# 50%      3.000000   28.000000    0.000000    0.000000   14.454200    1.000000
# 75%      3.000000   35.000000    1.000000    0.000000   31.000000    1.000000
# max      3.000000   80.000000    8.000000    6.000000  512.329200    1.000000
#
#         Same_Last   ticket_suffix  Embarked_S  Embarked_C  \
# count  891.000000      891.000000  891.000000  891.000000
# mean     0.882155   297745.874299    0.722783    0.188552
# std      1.488014   656159.899304    0.447876    0.391372
# min      0.000000      541.000000    0.000000    0.000000
# 25%      0.000000    14882.000000    0.000000    0.000000
# 50%      0.000000   112379.000000    1.000000    0.000000
# 75%      1.000000   347082.000000    1.000000    0.000000
# max      8.000000  3101317.000000    1.000000    1.000000
#
#                  ...             ticket_prefix_A/S  ticket_prefix_SC/AH Basle  \
# count            ...                    891.000000                 891.000000
# mean             ...                      0.001122                   0.001122
# std              ...                      0.033501                   0.033501
# min              ...                      0.000000                   0.000000
# 25%              ...                      0.000000                   0.000000
# 50%              ...                      0.000000                   0.000000
# 75%              ...                      0.000000                   0.000000
# max              ...                      1.000000                   1.000000
#
#        ticket_prefix_A/4  ticket_prefix_WE/P  ticket_prefix_S.W./PP  \
# count         891.000000          891.000000             891.000000
# mean            0.003367            0.002245               0.001122
# std             0.057961            0.047351               0.033501
# min             0.000000            0.000000               0.000000
# 25%             0.000000            0.000000               0.000000
# 50%             0.000000            0.000000               0.000000
# 75%             0.000000            0.000000               0.000000
# max             1.000000            1.000000               1.000000
#
#        ticket_prefix_S.O./P.P.  ticket_prefix_F.C.  ticket_prefix_SOTON/O2  \
# count               891.000000          891.000000              891.000000
# mean                  0.003367            0.001122                0.002245
# std                   0.057961            0.033501                0.047351
# min                   0.000000            0.000000                0.000000
# 25%                   0.000000            0.000000                0.000000
# 50%                   0.000000            0.000000                0.000000
# 75%                   0.000000            0.000000                0.000000
# max                   1.000000            1.000000                1.000000
#
#        ticket_prefix_S.C./PARIS  ticket_prefix_C.A./SOTON
# count                891.000000                891.000000
# mean                   0.002245                  0.001122
# std                    0.047351                  0.033501
# min                    0.000000                  0.000000
# 25%                    0.000000                  0.000000
# 50%                    0.000000                  0.000000
# 75%                    0.000000                  0.000000
# max                    1.000000                  1.000000
#
# [8 rows x 82 columns]

# %%
X_train, X_valid, Y_train, Y_valid = train_test_split(train_x, train_y, test_size=0.15, random_state=0)

# %%
def cross_validation(train_x,train_y,p_range,k=50,parameter='C',silence=True,**kwargs):
    errors = []
    for p in p_range:
        kfold = KFold(len(train_x), n_folds=k,shuffle=True)
        error = 0
        params = dict({parameter:p},**kwargs)
        for train_index, val_index in kfold:
            x_train = train_x.iloc[train_index]
            y_train = train_y[train_index]
            x_val = train_x.iloc[val_index]
            y_val = train_y[val_index]
            clf = linear_model.LogisticRegression(**params)
            clf.fit(x_train,y_train)
            predictions = clf.predict(x_val)
            err = np.sum((predictions != y_val),dtype=float)/len(y_val)
            error += err/k
        if silence != True:
            print p,':',error
        errors.append(error)
    best = p_range[np.argmin(errors)]
    return best,errors

# %%
c_range = np.logspace(-10,10,210)
best_c,c_errors = cross_validation(X_train,Y_train,c_range,parameter='C',silence=False)
# Out:
# 1e-10 : 0.378666666667
# 1.24650429684e-10 : 0.379083333333
# 1.55377296204e-10 : 0.379
# 1.9367846735e-10 : 0.378666666667
# 2.41421041757e-10 : 0.379333333333
# 3.00932365898e-10 : 0.3785
# 3.7511348715e-10 : 0.378833333333
# 4.67580573536e-10 : 0.378583333333
# 5.82841194032e-10 : 0.379666666667
# 7.26514052736e-10 : 0.379666666667
# 9.0560288845e-10 : 0.379083333333
# 1.12883789168e-09 : 0.378666666667
# 1.40710128242e-09 : 0.379666666667
# 1.75395779463e-09 : 0.379416666667
# 2.18631592748e-09 : 0.379416666667
# 2.72525219786e-09 : 0.379
# 3.3970385746e-09 : 0.378583333333
# 4.23442317977e-09 : 0.3795
# 5.27822668823e-09 : 0.3795
# 6.57933224658e-09 : 0.379083333333
# 8.2011659157e-09 : 0.37925
# 1.0222788553e-08 : 0.379
# 1.2742749857e-08 : 0.377833333333
# 1.58838924504e-08 : 0.376833333333
# 1.97993401899e-08 : 0.374833333333
# 2.46799626213e-08 : 0.385583333333
# 3.07636794534e-08 : 0.386666666667
# 3.83470586252e-08 : 0.384166666667
# 4.77997733476e-08 : 0.38225
# 5.95826228657e-08 : 0.374166666667
# 7.42699954192e-08 : 0.374666666667
# 9.25778684163e-08 : 0.375
# 1.15398710773e-07 : 0.365833333333
# 1.43844988829e-07 : 0.354
# 1.79303396654e-07 : 0.347833333333
# 2.23502454367e-07 : 0.349833333333
# 2.78596769723e-07 : 0.350083333333
# 3.47272070546e-07 : 0.3505
# 4.32876128108e-07 : 0.342333333333
# 5.39581953687e-07 : 0.33975
# 6.72591223768e-07 : 0.330333333333
# 8.38387850444e-07 : 0.332833333333
# 1.045054058e-06 : 0.327833333333
# 1.30266437372e-06 : 0.326416666667
# 1.62377673919e-06 : 0.3265
# 2.02404468251e-06 : 0.322166666667
# 2.52298039374e-06 : 0.326583333333
# 3.14490590165e-06 : 0.325166666667
# 3.92013871956e-06 : 0.3275
# 4.88646975814e-06 : 0.322916666667
# 6.09100554991e-06 : 0.317333333333
# 7.59246459004e-06 : 0.319833333333
# 9.46403973509e-06 : 0.3195
# 1.17969661953e-05 : 0.315166666667
# 1.47049690521e-05 : 0.314666666667
# 1.83298071083e-05 : 0.318916666667
# 2.28481833208e-05 : 0.321
# 2.84803586844e-05 : 0.319833333333
# 3.55008894756e-05 : 0.324666666667
# 4.4252011273e-05 : 0.32125
# 5.51603221956e-05 : 0.334416666667
# 6024.26830871 : 0.33525
# 7509.27633213 : 0.332333333333
# 9360.34521416 : 0.332583333333
# 11667.7105294 : 0.333
# 14543.8513091 : 0.331833333333
# 18128.9731495 : 0.330166666667
# 22597.8429281 : 0.32825
# 28168.3083092 : 0.33175
# 35111.9173422 : 0.3325
# 43767.1558373 : 0.331833333333
# 54555.9478117 : 0.334416666667
# 68004.2233655 : 0.332833333333
# 84767.5566284 : 0.329083333333
# 105663.12357 : 0.331416666667
# 131709.537548 : 0.336
# 164176.504488 : 0.333416666667
# 204646.718284 : 0.33375
# 255093.013676 : 0.332
# 317974.537641 : 0.3315
# 396356.627455 : 0.3305
# 494060.239204 : 0.33125
# 615848.211066 : 0.33125
# 767657.441295 : 0.334166666667
# 956888.299076 : 0.333
# 1192765.37639 : 0.33175
# 1486787.1668 : 0.33275
# 1853286.5919 : 0.3315
# 2310129.70008 : 0.331583333333
# 2879586.59741 : 0.331916666667
# 3589417.0668 : 0.333
# 4474223.79692 : 0.334083333333
# 5577139.18788 : 0.333916666667
# 6951927.96178 : 0.332916666667
# 8665608.07568 : 0.333
# 10801717.7011 : 0.330333333333
# 13464387.5276 : 0.33025
# 16783416.9075 : 0.333916666667
# 20920601.2909 : 0.328333333333
# 26077619.4016 : 0.331916666667
# 32505864.6355 : 0.334583333333
# 40518699.9406 : 0.33175
# 50506733.5784 : 0.3345
# 62956860.4248 : 0.333916666667
# 78475997.0351 : 0.331583333333
# 97820667.5032 : 0.33
# 121933882.362 : 0.331416666667
# 151991108.295 : 0.331166666667
# 189457569.572 : 0.333916666667
# 236159674.54 : 0.333583333333
# 294374049.055 : 0.330416666667
# 366938517.025 : 0.332333333333
# 457390438.148 : 0.33275
# 570139146.485 : 0.3295
# 710680895.891 : 0.332916666667
# 885866790.41 : 0.333083333333
# 1104236760.67 : 0.331333333333
# 1376435866.91 : 0.330583333333
# 1715733222.43 : 0.330166666667
# 2138668833.99 : 0.333083333333
# 2665859891.09 : 0.3315
# 3323005809.01 : 0.332083333333
# 4142141019.36 : 0.334583333333
# 5163196578.76 : 0.332083333333
# 6435946720.85 : 0.334166666667
# 8022435241.78 : 0.329916666667
# 10000000000.0 : 0.334083333333

# %%
best_c
# Out:
# 1.4704969052079676e-05

# %%
lrc = linear_model.LogisticRegression(C=best_c)
lrc.fit(X_train,Y_train)
# Out:
# LogisticRegression(C=1.4704969052079676e-05, class_weight=None, dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', penalty='l2', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0)

# %%
predictions = lrc.predict(X_valid)
print error_rate(predictions,Y_valid)
# Out:
# 0.283582089552

# %%
np.savetxt('Predictions/train_lrc_predictions.csv',
           np.c_[predictions],
           delimiter=',',
           fmt='%d',
           comments='')

# %%
test_data = pd.read_csv('data_sets/test.csv')
test = preprocess_test(test_data,train_x)
test.to_csv('data_sets/preprocessed__test_v1.csv')

# %%
test_predictions = lrc.predict(test)
np.savetxt('Predictions/test_lrc_predictions.csv',
           np.c_[test_predictions],
           delimiter=',',
           fmt='%d',
           comments='')
