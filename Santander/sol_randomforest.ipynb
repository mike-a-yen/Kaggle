# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.cross_validation import train_test_split
from sklearn.cross_validation import KFold
import matplotlib.pyplot as plt
plt.style.use('bmh')
# %matplotlib inline

# %%
train_raw = pd.read_csv('data_sets/train.csv')
train_raw.describe()
# Out:
#                   ID           var3         var15  imp_ent_var16_ult1  \
# count   76020.000000   76020.000000  76020.000000        76020.000000
# mean    75964.050723   -1523.199277     33.212865           86.208265
# std     43781.947379   39033.462364     12.956486         1614.757313
# min         1.000000 -999999.000000      5.000000            0.000000
# 25%     38104.750000       2.000000     23.000000            0.000000
# 50%     76043.000000       2.000000     28.000000            0.000000
# 75%    113748.750000       2.000000     40.000000            0.000000
# max    151838.000000     238.000000    105.000000       210000.000000
#
#        imp_op_var39_comer_ult1  imp_op_var39_comer_ult3  \
# count             76020.000000             76020.000000
# mean                 72.363067               119.529632
# std                 339.315831               546.266294
# min                   0.000000                 0.000000
# ...

# %%
train_x = train_raw.drop(['TARGET'],axis=1)
train_y = train_raw['TARGET'].values
print train_x.shape
print train_y.shape
# Out:
# (76020, 370)
# (76020,)

# %%
X_train, X_valid, Y_train, Y_valid = train_test_split(train_x, train_y, test_size=0.5, 
                                                      random_state=42)

# %%
clf = RandomForestClassifier(n_estimators=500)
clf.fit(X_train[['var3','imp_ent_var16_ult1']],Y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
predictions = clf.predict(X_valid[['var3','imp_ent_var16_ult1']])

# %%
print predictions.sum()
print Y_valid.sum()
# Out:
# 25
# 1481

# %%
error = np.sum(predictions != Y_valid,dtype=float)/len(Y_valid)
print error
# Out:
# 0.0395685345962

# %% [markdown]
# # Test Data!!!

# %%
test_raw = pd.read_csv('data_sets/test.csv')
test_raw.describe()
# Out:
#                   ID           var3         var15  imp_ent_var16_ult1  \
# count   75818.000000   75818.000000  75818.000000        75818.000000
# mean    75874.830581   -1579.955011     33.138832           83.164329
# std     43882.370827   39752.473358     12.932000         1694.873886
# min         2.000000 -999999.000000      5.000000            0.000000
# 25%     37840.250000       2.000000     23.000000            0.000000
# 50%     75810.000000       2.000000     27.000000            0.000000
# 75%    113996.500000       2.000000     39.000000            0.000000
# max    151837.000000     238.000000    105.000000       240000.000000
#
#        imp_op_var39_comer_ult1  imp_op_var39_comer_ult3  \
# count             75818.000000             75818.000000
# mean                 74.312894               123.136448
# std                 364.211245               606.431562
# min                   0.000000                 0.000000
# ...

# %%
clf = RandomForestClassifier(n_estimators=500)
clf.fit(train_x,train_y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
test_predictions = clf.predict(test_raw)

# %%
np.savetxt('santander_RF_naive.csv',
           np.c_[test_raw['ID'],test_predictions],
           delimiter=',',
           header='ID,TARGET',
           fmt='%d',
           comments='')

# %%
train_x.mean().order()
# Out:
# var3                                -1523.199277
# num_var46_0                             0.000000
# ind_var2                                0.000000
# num_var41                               0.000000
# num_var27                               0.000000
# num_var28                               0.000000
# num_var28_0                             0.000000
# num_var27_0                             0.000000
# num_reemb_var33_hace3                   0.000000
# ind_var46                               0.000000
# ind_var46_0                             0.000000
# ind_var41                               0.000000
# ind_var27                               0.000000
# ind_var28                               0.000000
# ind_var28_0                             0.000000
# ind_var27_0                             0.000000
# num_var46                               0.000000
# num_reemb_var13_hace3                   0.000000
# ind_var2_0                              0.000000
# ...
